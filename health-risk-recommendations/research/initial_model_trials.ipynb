# %% [markdown]
# import pandas as pd
#
# df = pd.read_csv("data/synthetic_health_data.csv")
# print(df.head())
# print(df.info())

# %%
import pandas as pd

df = pd.read_csv("data/synthetic_health_data.csv")
print(df.head())
print(df.info())
